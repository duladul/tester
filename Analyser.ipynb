# %%
import pandas as pd

# %%
adf = pd.read_parquet("agent_data.pq")
mdf = pd.read_parquet("model_data.pq")
mdf.avg_profit = mdf.avg_profit.fillna(0)

# %%
df = pd.merge(adf, mdf, how='left', on='step')

# %%
df
# Out:
#       step  id   agent_type      venit       cost   pos_lat   pos_lon  \
# 0        0   1    Depozitar   0.000000   0.000000  0.616571  0.448665
# 1        0   2    Depozitar   0.000000   0.000000  0.612286  0.668073
# 2        0   3    Depozitar   0.000000   0.000000  0.333543  0.444601
# 3        0   4  Transportor   0.000000   0.000000  0.551986  0.730652
# 4        0   5  Transportor   0.000000   0.000000  0.897287  0.453773
# ...    ...  ..          ...        ...        ...       ...       ...
# 4897   777   4  Transportor  10.624922  70.327133  0.473640  0.742881
# 4898   778   4  Transportor  10.624922  70.417644  0.485365  0.753928
# 4899   779   4  Transportor  10.624922  70.508156  0.500316  0.763342
# 4900   780   4  Transportor  10.624922  70.598667  0.491996  0.758104
# 4901   781   4  Transportor  10.624922  70.689178  0.480939  0.751141
#
#       dest_lat  dest_lon  timp_trecut_s  avg_profit
# 0     0.616571  0.448665              0    0.000000
# ...
